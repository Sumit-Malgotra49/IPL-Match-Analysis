# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('IPLMATCH.csv')
df.head()
# Out:
#    ballnumber  inningno  over outcome           batter          bowler  \
# 0           1         1   0.1       0     Devon Conway  Mohammed Shami
# 1           2         1   0.2     1lb     Devon Conway  Mohammed Shami
# 2           3         1   0.3       0  Ruturaj Gaikwad  Mohammed Shami
# 3           4         1   0.4       1  Ruturaj Gaikwad  Mohammed Shami
# 4           5         1   0.5       0     Devon Conway  Mohammed Shami
#
#                                       comment
# 0     Mohammed Shami to Devon Conway, no run,
# 1  Mohammed Shami to Devon Conway, 1 leg bye,
# 2  Mohammed Shami to Ruturaj Gaikwad, no run,
# 3   Mohammed Shami to Ruturaj Gaikwad, 1 run,
# 4     Mohammed Shami to Devon Conway, no run,

# %%
# Getting the information of the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ballnumber  243 non-null    int64
#  1   inningno    243 non-null    int64
#  2   over        243 non-null    float64
#  3   outcome     243 non-null    object
#  4   batter      243 non-null    object
#  5   bowler      243 non-null    object
#  6   comment     243 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 13.4+ KB

# %%
# Checking duplicate data
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#spilliting the data
df1= df.iloc[:121, :]
df1.reset_index
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ballnumber  121 non-null    int64
#  1   inningno    121 non-null    int64
#  2   over        121 non-null    float64
#  3   outcome     121 non-null    object
#  4   batter      121 non-null    object
#  5   bowler      121 non-null    object
#  6   comment     121 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 6.7+ KB

# %%
df2 = df.iloc[121:, :]
df2.reset_index
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 121 to 242
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ballnumber  122 non-null    int64
#  1   inningno    122 non-null    int64
#  2   over        122 non-null    float64
#  3   outcome     122 non-null    object
#  4   batter      122 non-null    object
#  5   bowler      122 non-null    object
#  6   comment     122 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 6.8+ KB

# %%
#checking both data sets
df1
# Out:
#      ballnumber  inningno  over outcome            batter          bowler  \
# 0             1         1   0.1       0      Devon Conway  Mohammed Shami
# 1             2         1   0.2     1lb      Devon Conway  Mohammed Shami
# 2             3         1   0.3       0   Ruturaj Gaikwad  Mohammed Shami
# 3             4         1   0.4       1   Ruturaj Gaikwad  Mohammed Shami
# 4             5         1   0.5       0      Devon Conway  Mohammed Shami
# ..          ...       ...   ...     ...               ...             ...
# 116         117         1  19.2     1lb  Mitchell Santner     Josh Little
# 117         118         1  19.3       6          MS Dhoni     Josh Little
# 118         119         1  19.4       4          MS Dhoni     Josh Little
# 119         120         1  19.5       0          MS Dhoni     Josh Little
# 120         121         1  19.6       1          MS Dhoni     Josh Little
#
#                                          comment
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 121 to 242
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ballnumber  122 non-null    int64
#  1   inningno    122 non-null    int64
#  2   over        122 non-null    float64
#  3   outcome     122 non-null    object
#  4   batter      122 non-null    object
#  5   bowler      122 non-null    object
#  6   comment     122 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 6.8+ KB

# %%
df.head()
# Out:
#    ballnumber  inningno  over outcome           batter          bowler  \
# 0           1         1   0.1       0     Devon Conway  Mohammed Shami
# 1           2         1   0.2     1lb     Devon Conway  Mohammed Shami
# 2           3         1   0.3       0  Ruturaj Gaikwad  Mohammed Shami
# 3           4         1   0.4       1  Ruturaj Gaikwad  Mohammed Shami
# 4           5         1   0.5       0     Devon Conway  Mohammed Shami
#
#                                       comment
# 0     Mohammed Shami to Devon Conway, no run,
# 1  Mohammed Shami to Devon Conway, 1 leg bye,
# 2  Mohammed Shami to Ruturaj Gaikwad, no run,
# 3   Mohammed Shami to Ruturaj Gaikwad, 1 run,
# 4     Mohammed Shami to Devon Conway, no run,

# %%
df1 = df1.reset_index(drop=True)
df1
# Out:
#      ballnumber  inningno  over outcome            batter          bowler  \
# 0             1         1   0.1       0      Devon Conway  Mohammed Shami
# 1             2         1   0.2     1lb      Devon Conway  Mohammed Shami
# 2             3         1   0.3       0   Ruturaj Gaikwad  Mohammed Shami
# 3             4         1   0.4       1   Ruturaj Gaikwad  Mohammed Shami
# 4             5         1   0.5       0      Devon Conway  Mohammed Shami
# ..          ...       ...   ...     ...               ...             ...
# 116         117         1  19.2     1lb  Mitchell Santner     Josh Little
# 117         118         1  19.3       6          MS Dhoni     Josh Little
# 118         119         1  19.4       4          MS Dhoni     Josh Little
# 119         120         1  19.5       0          MS Dhoni     Josh Little
# 120         121         1  19.6       1          MS Dhoni     Josh Little
#
#                                          comment
# ...

# %%
df2 = df2.reset_index(drop=True)
df2
# Out:
#      ballnumber  inningno  over outcome           batter            bowler  \
# 0             1         2   0.1       0  Wriddhiman Saha     Deepak Chahar
# 1             2         2   0.2       0  Wriddhiman Saha     Deepak Chahar
# 2             3         2   0.3       0  Wriddhiman Saha     Deepak Chahar
# 3             4         2   0.4       1  Wriddhiman Saha     Deepak Chahar
# 4             5         2   0.5       2     Shubman Gill     Deepak Chahar
# ..          ...       ...   ...     ...              ...               ...
# 117         118         2  18.5       4      Rashid Khan     Deepak Chahar
# 118         119         2  18.6       0      Rashid Khan     Deepak Chahar
# 119         120         2  19.1     1wd    Rahul Tewatia  Tushar Deshpande
# 120         121         2  19.1       6    Rahul Tewatia  Tushar Deshpande
# 121         122         2  19.2       4    Rahul Tewatia  Tushar Deshpande
#
#                                         comment
# ...

# %% [markdown]
# # Balls played by CSK batters

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x=df1['batter'])
plt.show()

# %% [markdown]
# # Balls Played by GT Batters

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x=df2['batter'])
plt.show()

# %% [markdown]
# # Balls Bowled by GT bowlers

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x=df1['bowler'])
plt.show()

# %% [markdown]
# # Balls Bowled by CSK Bowlers

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x=df2['bowler'])
plt.show()

# %% [markdown]
# # Number of sixes scored by CSK batters

# %%
sixes1 = df1[df1['outcome'] == "6"]
sixes1
# Out:
#      ballnumber  inningno  over outcome           batter          bowler  \
# 18           19         1   3.1       6  Ruturaj Gaikwad     Josh Little
# 28           29         1   4.4       6        Moeen Ali  Mohammed Shami
# 39           40         1   6.3       6  Ruturaj Gaikwad   Hardik Pandya
# 40           41         1   6.4       6  Ruturaj Gaikwad   Hardik Pandya
# 49           50         1   8.1       6  Ruturaj Gaikwad  Alzarri Joseph
# 52           53         1   8.4       6  Ruturaj Gaikwad  Alzarri Joseph
# 54           55         1   8.6       6  Ruturaj Gaikwad  Alzarri Joseph
# 66           67         1  10.6       6  Ruturaj Gaikwad     Josh Little
# 69           70         1  11.3       6  Ruturaj Gaikwad      Yash Dayal
# 72           73         1  11.6       6    Ambati Rayudu      Yash Dayal
# 97           98         1  16.1       6  Ruturaj Gaikwad     Rashid Khan
# 110         111         1  18.2       6      Shivam Dube  Mohammed Shami
# ...

# %%
sixes1['batter'].value_counts()
# Out:
# batter
# Ruturaj Gaikwad    9
# Moeen Ali          1
# Ambati Rayudu      1
# Shivam Dube        1
# MS Dhoni           1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x=sixes1['batter'])
plt.show()

# %%
sixes2 = df2[df2['outcome'] == "6"]
sixes2
plt.figure(figsize=(15, 6))
sns.countplot(x=sixes2['batter'])
plt.show()

# %% [markdown]
# # Most Sixes given by bowlers

# %%
sixes1 = df1[df1['outcome'] == "6"]
sixes1

plt.figure(figsize=(15, 6))
sns.countplot(x=sixes1['bowler'])
plt.show()

# %%
sixes2 = df2[df2['outcome'] == "6"]
sixes2
plt.figure(figsize=(15, 6))
sns.countplot(x=sixes2['bowler'])
plt.show()
